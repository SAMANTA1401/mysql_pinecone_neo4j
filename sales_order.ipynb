# %%
import mysql.connector

conn = mysql.connector.connect(  #establishing the connection
    host = "localhost",
    user="root",
    passwd = "mYsql@2022",
    # database = "sample2"
)

# %%
cursor = conn.cursor()

# %%
cursor.execute("""show databases""")

# %%
cursor.fetchall()
# Out:
# [('ecom',),
#  ('information_schema',),
#  ('mysql',),
#  ('pandeyji_eatery',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sample2',),
#  ('student_registration',),
#  ('sys',),
#  ('test_db',),
#  ('world',)]

# %%
cursor.execute("""create database SaleOrder""")

# %%
cursor.execute("""use SaleOrder""")

# %%
cursor.execute("""create table customer(
    CustomerID int NOT null primary key, 
    CustomerFirstName varchar(50) NOT null, 
    CustomerLastName varchar(50) NOT null, 
    CustomerAddress varchar(50) NOT null, 
    CustomerSuburb varchar(50) null, 
    CustomerCity varchar(50) NOT null, 
    CustomerPostCode char(4) null, 
    CustomerPhoneNumber char(12) null 
)""")

# %%
cursor.execute("""create table inventory ( 
            InventoryID tinyint NOT null primary key, 
            InventoryName varchar(50) NOT null, 
            InventoryDescription varchar(255) null
            )""")

# %%
cursor.execute("""create table employee ( 
EmployeeID tinyint NOT null primary key, 
EmployeeFirstName varchar(50) NOT null, 
EmployeeLastName varchar(50) NOT null, 
EmployeeExtension char(4) null
)""")

# %% [markdown]
# Foreign key references

# %%
cursor.execute("""create table sale ( 
                    SaleID int not null primary key, 
                    CustomerID int not null references customer(CustomerID), 
                    InventoryID int not null references Inventory(InventoryID), 
                    EmployeeID int not null references Employee(EmployeeID), 
                    SaleDate date not null, 
                    SaleQuantity int not null, 
                    SaleUnitPrice DECIMAL(10, 2) not null 
)""")

# %%
cursor.execute("""
    INSERT INTO customer (
        CustomerID, 
        CustomerFirstName, 
        CustomerLastName, 
        CustomerAddress, 
        CustomerSuburb, 
        CustomerCity, 
        CustomerPostCode, 
        CustomerPhoneNumber
    ) 
    VALUES 
        (1, 'John', 'Doe', '123 Main St', 'Anytown', 'Melbourne', '3000', '0412 345 678'),
        (2, 'Jane', 'Smith', '456 High St', 'Othertown', 'Sydney', '2000', '0434 567 890'),
        (3, 'Bob', 'Johnson', '789 Low St', 'Thistown', 'Brisbane', '4000', '0456 789 012'),
        (4, 'Alice', 'Williams', '321 Elm St', 'Thatville', 'Perth', '6000', '0487 890 123'),
        (5, 'Mike', 'Davis', '901 Oak St', 'Someplace', 'Adelaide', '5000', '0411 234 567'),
        (6, 'Emma', 'Miller', '345 Maple St', 'Elsewhere', 'Hobart', '7000', '0433 456 789'),
        (7, 'Tom', 'Wilson', '678 Pine St', 'Another town', 'Darwin', '0800', '0455 678 901'),
        (8, 'Sophia', 'Moore', '234 Cedar St', 'This town', 'Canberra', '2600', '0488 901 234'),
        (9, 'Oliver', 'Taylor', '567 Cypress St', 'That town', 'Gold Coast', '4217', '0414 567 890'),
        (10, 'Mia', 'Anderson', '890 Walnut St', 'Some town', 'Newcastle', '2300', '0435 678 901'),
        (11, 'William', 'Thomas', '345 Spruce St', 'Anytown', 'Central Coast', '2250', '0457 789 012'),
        (12, 'Charlotte', 'Jackson', '678 Fir St', 'Othertown', 'Wollongong', '2500', '0489 012 345'),
        (13, 'James', 'White', '901 Beech St', 'Thistown', 'Geelong', '3220', '0416 789 012'),
        (14, 'Amelia', 'Harris', '234 Ash St', 'Thatville', 'Townsville', '4810', '0438 901 234'),
        (15, 'George', 'Martin', '567 Oak St', 'Someplace', 'Cairns', '4870', '0459 012 345'),
        (16, 'Harriet', 'Thompson', '890 Maple St', 'Elsewhere', 'Toowoomba', '4350', '0481 234 567'),
        (17, 'Benjamin', 'Walker', '345 Pine St', 'Another town', 'Ballarat', '3350', '0418 901 234'),
        (18, 'Abigail', 'Allen', '678 Cedar St', 'This town', 'Bendigo', '3550', '0439 012 345'),
        (19, 'Logan', 'Scott', '901 Cypress St', 'That town', 'Mackay', '4740', '0450 123 456'),
        (20, 'Ava', 'Coleman', '234 Walnut St', 'Some town', 'Rockhampton', '4700', '0482 345 678')
""")

# %%
conn.commit()

# %%
cursor.execute("""
    INSERT INTO inventory (
        InventoryID, 
        InventoryName, 
        InventoryDescription
    ) 
    VALUES 
        (1, 'Laptop', 'Dell Inspiron 15 5000 Series Laptop'),
        (2, 'Desktop', 'HP Pavilion Gaming Desktop'),
        (3, 'Printer', 'Epson Expression Home XP-4100 Printer'),
        (4, 'Scanner', 'Canon CanoScan LiDE 300 Scanner'),
        (5, 'Monitor', 'Acer R240HY 24" Full HD Monitor'),
        (6, 'Keyboard', 'Logitech K120 Keyboard'),
        (7, 'Mouse', 'Logitech M100 Mouse'),
        (8, 'Headset', 'HyperX Cloud II Gaming Headset'),
        (9, 'Webcam', 'Logitech C270 HD Webcam'),
        (10, 'Speaker', 'Edifier R1280T Powered Bluetooth Speaker')
""")

# %%
conn.commit()

# %%
cursor.execute("""
    INSERT INTO employee (
        EmployeeID, 
        EmployeeFirstName, 
        EmployeeLastName, 
        EmployeeExtension
    ) 
    VALUES 
        (1, 'John', 'Doe', '1234'),
        (2, 'Jane', 'Smith', '5678'),
        (3, 'Bob', 'Johnson', '9012'),
        (4, 'Alice', 'Williams', '3456'),
        (5, 'Mike', 'Davis', '7890'),
        (6, 'Emma', 'Miller', '2345'),
        (7, 'Tom', 'Wilson', '6789'),
        (8, 'Sophia', 'Moore', '4567'),
        (9, 'Oliver', 'Taylor', '8901'),
        (10, 'Mia', 'Anderson', '1234')
""")

# %%
conn.commit()

# %%
cursor.execute("""
    INSERT INTO sale (
        SaleID, 
        CustomerID, 
        InventoryID, 
        EmployeeID, 
        SaleDate, 
        SaleQuantity, 
        SaleUnitPrice
    ) 
    VALUES 
        (1, 1, 1, 1, '2022-01-01', 2, 1000.00),
        (2, 1, 2, 2, '2022-01-05', 1, 500.00),
        (3, 2, 3, 3, '2022-01-10', 3, 750.00),
        (4, 3, 1, 1, '2022-01-15', 1, 1000.00),
        (5, 4, 4, 4, '2022-01-20', 2, 2000.00),
        (6, 5, 5, 5, '2022-01-25', 1, 1500.00),
        (7, 6, 6, 6, '2022-02-01', 3, 1200.00),
        (8, 7, 7, 7, '2022-02-05', 2, 1800.00),
        (9, 8, 8, 8, '2022-02-10', 1, 2200.00),
        (10, 9, 9, 9, '2022-02-15', 2, 2500.00),
        (11, 10, 10, 10, '2022-02-20', 1, 2800.00),
        (12, 1, 1, 1, '2022-03-01', 3, 1000.00),
        (13, 2, 2, 2, '2022-03-05', 2, 500.00),
        (14, 3, 3, 3, '2022-03-10', 1, 750.00),
        (15, 4, 4, 4, '2022-03-15', 2, 2000.00),
        (16, 5, 5, 5, '2022-03-20', 1, 1500.00),
        (17, 6, 6, 6, '2022-04-01', 3, 1200.00),
        (18, 7, 7, 7, '2022-04-05', 2, 1800.00),
        (19, 8, 8, 8, '2022-04-10', 1, 2200.00),
        (20, 9, 9, 9, '2022-04-15', 2, 2500.00)
""")

# %%
conn.commit()

# %% [markdown]
# Check what table inside

# %%
cursor.execute("SELECT * FROM information_schema.tables")

# %%
cursor.fetchall()
# Out:
# [('def',
#   'mysql',
#   'innodb_table_stats',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   32,
#   512,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 17, 51, 9),
#   datetime.datetime(2025, 2, 26, 12, 26, 37),
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   ''),
#  ('def',
#   'mysql',
#   'innodb_index_stats',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   181,
#   271,
#   49152,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 17, 51, 9),
#   datetime.datetime(2025, 2, 26, 12, 26, 37),
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   ''),
#  ('def',
#   'information_schema',
#   'CHARACTER_SETS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'CHECK_CONSTRAINTS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'COLLATIONS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'COLLATION_CHARACTER_SET_APPLICABILITY',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'COLUMNS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'COLUMNS_EXTENSIONS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'COLUMN_STATISTICS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'EVENTS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'FILES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_DATAFILES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FOREIGN',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FOREIGN_COLS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FIELDS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_TABLESPACES_BRIEF',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'KEY_COLUMN_USAGE',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'KEYWORDS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'PARAMETERS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'PARTITIONS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'REFERENTIAL_CONSTRAINTS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'RESOURCE_GROUPS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'ROUTINES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'SCHEMATA',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'SCHEMATA_EXTENSIONS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'ST_SPATIAL_REFERENCE_SYSTEMS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'ST_UNITS_OF_MEASURE',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'ST_GEOMETRY_COLUMNS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'STATISTICS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'TABLE_CONSTRAINTS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'TABLE_CONSTRAINTS_EXTENSIONS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'TABLES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'TABLES_EXTENSIONS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'TABLESPACES_EXTENSIONS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'TRIGGERS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'VIEW_ROUTINE_USAGE',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'VIEW_TABLE_USAGE',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'VIEWS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'COLUMN_PRIVILEGES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'ENGINES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'OPTIMIZER_TRACE',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'PLUGINS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'PROCESSLIST',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'PROFILING',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'SCHEMA_PRIVILEGES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'TABLESPACES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'TABLE_PRIVILEGES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'USER_PRIVILEGES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'cond_instances',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'error_log',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   2683,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_current',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   1536,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_history',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   2560,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_history_long',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   10000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_summary_by_host_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   83712,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_summary_by_instance',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   10752,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_summary_by_thread_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   167424,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_summary_by_user_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   83712,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_summary_by_account_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   83712,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_waits_summary_global_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   654,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'file_instances',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   4096,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'file_summary_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   80,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'file_summary_by_instance',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   4096,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'host_cache',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   279,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'mutex_instances',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   4096,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'objects_summary_global_by_type',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   4096,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'performance_timers',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   5,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'processlist',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'rwlock_instances',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   2048,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'setup_actors',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   128,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'setup_consumers',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   16,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'setup_instruments',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   1500,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'setup_objects',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   128,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'setup_threads',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   100,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'table_io_waits_summary_by_index_usage',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   8192,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'table_io_waits_summary_by_table',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   4096,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'table_lock_waits_summary_by_table',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   4096,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'threads',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_stages_current',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_stages_history',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   2560,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_stages_history_long',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   10000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_stages_summary_by_thread_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   44800,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_stages_summary_by_account_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   22400,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_stages_summary_by_user_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   22400,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_stages_summary_by_host_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   22400,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_stages_summary_global_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   175,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_current',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   2560,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_history',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   2560,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_history_long',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   10000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_summary_by_thread_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   56064,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_summary_by_account_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   28032,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_summary_by_user_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   28032,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_summary_by_host_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   28032,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_summary_global_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   219,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_summary_by_digest',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   10000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_summary_by_program',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_histogram_global',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   450,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_statements_histogram_by_digest',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   10000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_transactions_current',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_transactions_history',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   2560,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_transactions_history_long',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   10000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_transactions_summary_by_thread_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_transactions_summary_by_account_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   128,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_transactions_summary_by_user_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   128,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_transactions_summary_by_host_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   128,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_transactions_summary_global_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_errors_summary_by_user_by_error',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   209920,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_errors_summary_by_host_by_error',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   209920,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_errors_summary_by_account_by_error',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   209920,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_errors_summary_by_thread_by_error',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   419840,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'events_errors_summary_global_by_error',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   5314,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'users',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   128,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'accounts',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   128,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'hosts',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   128,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'socket_instances',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'socket_summary_by_instance',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'socket_summary_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   10,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'session_connect_attrs',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   131072,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_bin',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'session_account_connect_attrs',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   131072,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_bin',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'keyring_keys',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   96,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_bin',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'memory_summary_global_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   450,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'memory_summary_by_account_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   57600,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'memory_summary_by_host_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   57600,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'memory_summary_by_thread_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   115200,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'memory_summary_by_user_by_event_name',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   57600,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'table_handles',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   1024,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'metadata_locks',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   1024,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'data_locks',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   99999,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'data_lock_waits',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   99999,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_connection_configuration',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_group_members',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_connection_status',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_applier_configuration',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_applier_status',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_applier_status_by_coordinator',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   256,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_applier_status_by_worker',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   8192,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_group_member_stats',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_applier_filters',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_applier_global_filters',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_asynchronous_connection_failover',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Fixed',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'replication_asynchronous_connection_failover_managed',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'log_status',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'prepared_statements_instances',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'user_variables_by_thread',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   2560,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'status_by_account',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   33024,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'status_by_host',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   33024,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'status_by_thread',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   66048,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'status_by_user',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   33024,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'global_status',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   258,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'session_status',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   258,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'variables_by_thread',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   172800,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'global_variables',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   675,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'session_variables',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   675,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'variables_info',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   675,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'persisted_variables',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'user_defined_functions',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   16,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'binary_log_transaction_compression_stats',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'tls_channel_status',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   96,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'keyring_component_status',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   64,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 9),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'mysql',
#   'db',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   2,
#   8192,
#   16384,
#   0,
#   16384,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Database privileges'),
#  ('def',
#   'mysql',
#   'user',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   4,
#   4096,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Users and global privileges'),
#  ('def',
#   'mysql',
#   'default_roles',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Default roles'),
#  ('def',
#   'mysql',
#   'role_edges',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Role hierarchy and role grants'),
#  ('def',
#   'mysql',
#   'global_grants',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   49,
#   1003,
#   49152,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Extended global grants'),
#  ('def',
#   'mysql',
#   'password_history',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Password history for user accounts'),
#  ('def',
#   'mysql',
#   'func',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'User defined functions'),
#  ('def',
#   'mysql',
#   'plugin',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'MySQL plugins'),
#  ('def',
#   'mysql',
#   'help_topic',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   940,
#   1690,
#   1589248,
#   0,
#   98304,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'help topics'),
#  ('def',
#   'mysql',
#   'help_category',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   53,
#   309,
#   16384,
#   0,
#   16384,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'help categories'),
#  ('def',
#   'mysql',
#   'help_relation',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   1745,
#   56,
#   98304,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'keyword-topic relation'),
#  ('def',
#   'mysql',
#   'servers',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'MySQL Foreign Servers table'),
#  ('def',
#   'mysql',
#   'tables_priv',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   2,
#   8192,
#   16384,
#   0,
#   16384,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Table privileges'),
#  ('def',
#   'mysql',
#   'columns_priv',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Column privileges'),
#  ('def',
#   'mysql',
#   'help_keyword',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   939,
#   139,
#   131072,
#   0,
#   131072,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'help keywords'),
#  ('def',
#   'mysql',
#   'time_zone_name',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Time zone names'),
#  ('def',
#   'mysql',
#   'time_zone',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   1,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Time zones'),
#  ('def',
#   'mysql',
#   'time_zone_transition',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Time zone transitions'),
#  ('def',
#   'mysql',
#   'time_zone_transition_type',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Time zone transition types'),
#  ('def',
#   'mysql',
#   'time_zone_leap_second',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Leap seconds information for time zones'),
#  ('def',
#   'mysql',
#   'procs_priv',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   16384,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_bin',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
#   'Procedure privileges'),
#  ('def',
#   'mysql',
#   'general_log',
#   'BASE TABLE',
#   'CSV',
#   10,
#   'Dynamic',
#   2,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   '',
#   'General log'),
#  ('def',
#   'mysql',
#   'slow_log',
#   'BASE TABLE',
#   'CSV',
#   10,
#   'Dynamic',
#   2,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   '',
#   'Slow log'),
#  ('def',
#   'mysql',
#   'component',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   1,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC',
#   'Components'),
#  ('def',
#   'mysql',
#   'slave_relay_log_info',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   0,
#   0,
#   16384,
#   0,
#   0,
#   4194304,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 12),
#   None,
#   None,
#   'utf8mb3_general_ci',
#   None,
#   'row_format=DYNAMIC stats_persistent=0',
# ...
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'ROLE_COLUMN_GRANTS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 13),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'ROLE_ROUTINE_GRANTS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 13),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'ROLE_TABLE_GRANTS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 13),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'USER_ATTRIBUTES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 13),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_CMP',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_CMPMEM',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_TRX',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_CMP_PER_INDEX',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_CMP_RESET',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FT_DELETED',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_BUFFER_POOL_STATS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_CMPMEM_RESET',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_BUFFER_PAGE_LRU',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_CMP_PER_INDEX_RESET',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FT_CONFIG',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_BUFFER_PAGE',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_TABLESPACES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FT_BEING_DELETED',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_TEMP_TABLE_INFO',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FT_DEFAULT_STOPWORD',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_METRICS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FT_INDEX_CACHE',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_FT_INDEX_TABLE',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_TABLES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_TABLESTATS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_INDEXES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_COLUMNS',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_VIRTUAL',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_CACHED_INDEXES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'information_schema',
#   'INNODB_SESSION_TEMP_TABLESPACES',
#   'SYSTEM VIEW',
#   None,
#   10,
#   None,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 21, 15),
#   None,
#   None,
#   None,
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'actor',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   200,
#   81,
#   16384,
#   0,
#   16384,
#   0,
#   200,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'address',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   603,
#   163,
#   98304,
#   0,
#   16384,
#   0,
#   605,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'category',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   16,
#   1024,
#   16384,
#   0,
#   0,
#   0,
#   16,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'city',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   600,
#   81,
#   49152,
#   0,
#   16384,
#   0,
#   600,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'country',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   109,
#   150,
#   16384,
#   0,
#   0,
#   0,
#   109,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'customer',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   599,
#   136,
#   81920,
#   0,
#   49152,
#   0,
#   599,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'film',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   1000,
#   196,
#   196608,
#   0,
#   81920,
#   0,
#   1000,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'film_actor',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   5462,
#   35,
#   196608,
#   0,
#   81920,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'film_category',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   1000,
#   65,
#   65536,
#   0,
#   16384,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'film_text',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   1000,
#   180,
#   180224,
#   0,
#   16384,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'inventory',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   4581,
#   39,
#   180224,
#   0,
#   196608,
#   0,
#   4581,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'language',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   6,
#   2730,
#   16384,
#   0,
#   0,
#   0,
#   6,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'payment',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   15400,
#   103,
#   1589248,
#   0,
#   638976,
#   0,
#   16049,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'rental',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   16005,
#   99,
#   1589248,
#   0,
#   1196032,
#   0,
#   16049,
#   datetime.datetime(2024, 7, 13, 23, 25, 19),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'staff',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   2,
#   32768,
#   65536,
#   0,
#   32768,
#   0,
#   2,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'store',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   2,
#   8192,
#   16384,
#   0,
#   32768,
#   0,
#   2,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'sakila',
#   'customer_list',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   None,
#   None,
#   None,
#   'VIEW'),
#  ('def',
#   'sakila',
#   'film_list',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   None,
#   None,
#   None,
#   'VIEW'),
#  ('def',
#   'sakila',
#   'nicer_but_slower_film_list',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   None,
#   None,
#   None,
#   'VIEW'),
#  ('def',
#   'sakila',
#   'staff_list',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   None,
#   None,
#   None,
#   'VIEW'),
#  ('def',
#   'sakila',
#   'sales_by_store',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   None,
#   None,
#   None,
#   'VIEW'),
#  ('def',
#   'sakila',
#   'sales_by_film_category',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   None,
#   None,
#   None,
#   'VIEW'),
#  ('def',
#   'sakila',
#   'actor_info',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 20),
#   None,
#   None,
#   None,
#   None,
#   None,
#   'VIEW'),
#  ('def',
#   'world',
#   'city',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   4046,
#   101,
#   409600,
#   0,
#   114688,
#   0,
#   4079,
#   datetime.datetime(2024, 7, 13, 23, 25, 22),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'world',
#   'country',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   239,
#   479,
#   114688,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 22),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'world',
#   'countrylanguage',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   984,
#   99,
#   98304,
#   0,
#   65536,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 25, 22),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'pandeyji_eatery',
#   'food_items',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   9,
#   1820,
#   16384,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 50, 31),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'pandeyji_eatery',
#   'order_tracking',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   8,
#   2048,
#   16384,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 50, 31),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'pandeyji_eatery',
#   'orders',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   15,
#   1092,
#   16384,
#   0,
#   16384,
#   0,
#   None,
#   datetime.datetime(2024, 7, 13, 23, 50, 31),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'test_db',
#   'emp_info',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   7,
#   2340,
#   16384,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 9, 23, 19, 51, 18),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'test_db',
#   'projects',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   10,
#   1638,
#   16384,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 9, 23, 21, 56, 25),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'test_db',
#   'breast_cancer',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   569,
#   345,
#   196608,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2024, 9, 24, 11, 36, 1),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'student_registration',
#   'login',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   8,
#   2048,
#   16384,
#   0,
#   0,
#   0,
#   16,
#   datetime.datetime(2024, 12, 7, 21, 28, 22),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'performance_schema',
#   'innodb_redo_log_files',
#   'BASE TABLE',
#   'PERFORMANCE_SCHEMA',
#   10,
#   'Dynamic',
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2025, 2, 26, 11, 26, 25),
#   None,
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'saleorder',
#   'customer',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   20,
#   819,
#   16384,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2025, 2, 26, 12, 1, 49),
#   datetime.datetime(2025, 2, 26, 12, 22, 9),
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'saleorder',
#   'inventory',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   10,
#   1638,
#   16384,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2025, 2, 26, 12, 4, 20),
#   datetime.datetime(2025, 2, 26, 12, 23, 34),
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'saleorder',
#   'employee',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   10,
#   1638,
#   16384,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2025, 2, 26, 12, 6, 15),
#   datetime.datetime(2025, 2, 26, 12, 24, 30),
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   ''),
#  ('def',
#   'saleorder',
#   'sale',
#   'BASE TABLE',
#   'InnoDB',
#   10,
#   'Dynamic',
#   20,
#   819,
#   16384,
#   0,
#   0,
#   0,
#   None,
#   datetime.datetime(2025, 2, 26, 12, 14, 16),
#   datetime.datetime(2025, 2, 26, 12, 26, 34),
#   None,
#   'utf8mb4_0900_ai_ci',
#   None,
#   '',
#   '')]

# %% [markdown]
# top: show only the first two row  from the table

# %%
# cursor.execute("SELECT top 2 * from customer") # microsoft sql server
cursor.execute("SELECT * from customer LIMIT 2") # mysql
result = cursor.fetchall()
print(result)
# Out:
# [(1, 'John', 'Doe', '123 Main St', 'Anytown', 'Melbourne', '3000', '0412 345 678'), (2, 'Jane', 'Smith', '456 High St', 'Othertown', 'Sydney', '2000', '0434 567 890')]

# %% [markdown]
# -top 40 percent: also means show the first two

# %%
# SELECT TOP 40 PERCENT * FROM customer; # for sql
cursor.execute("SELECT * FROM customer ORDER BY CustomerID ASC LIMIT FLOOR((SELECT COUNT(*) FROM customer) * 0.4)")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File d:\a27_YEARS_OLD\mysql\venv\Lib\site-packages\mysql\connector\connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '((SELECT COUNT(*) FROM customer) * 0.4)' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[32], line 2
#       1 # SELECT TOP 40 PERCENT * FROM customer; # for sql
# ----> 2 cursor.execute("SELECT * FROM customer ORDER BY CustomerID ASC LIMIT FLOOR((SELECT COUNT(*) FROM customer) * 0.4)")
#
# File d:\a27_YEARS_OLD\mysql\venv\Lib\site-packages\mysql\connector\cursor_cext.py:351, in CMySQLCursor.execute(self, operation, params, map_results)
#     343 self._executed = (
#     344     self._stmt_partition["single_stmts"].popleft()
#     345     if map_results
#     346     else self._stmt_partition["mappable_stmt"]
#     347 )
#     349 try:
#     350     self._handle_result(
# --> 351         self._connection.cmd_query(
#     352             self._stmt_partition["mappable_stmt"],
#     353             raw=self._raw,
#     354             buffered=self._buffered,
#     355             raw_as_string=self._raw_as_string,
#     356         )
#     357     )
#     358 except MySQLInterfaceError as err:
#     359     raise get_mysql_exception(
#     360         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     361     ) from err
#
# File d:\a27_YEARS_OLD\mysql\venv\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File d:\a27_YEARS_OLD\mysql\venv\Lib\site-packages\mysql\connector\connection_cext.py:763, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#    (...)
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
# --> 763     raise get_mysql_exception(
#     764         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     765     ) from err
#     766 except AttributeError as err:
#     767     addr = (
#     768         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     769     )
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '((SELECT COUNT(*) FROM customer) * 0.4)' at line 1

# %% [markdown]
# View specific column

# %% [markdown]
# order by

# %% [markdown]
# -sort result (by default is ascending)

# %%
cursor.execute("select CustomerFirstName, CustomerLastName from customer order by CustomerLastName desc")

# %%
cursor.fetchall()
# Out:
# [('Tom', 'Wilson'),
#  ('Alice', 'Williams'),
#  ('James', 'White'),
#  ('Benjamin', 'Walker'),
#  ('Harriet', 'Thompson'),
#  ('William', 'Thomas'),
#  ('Oliver', 'Taylor'),
#  ('Jane', 'Smith'),
#  ('Logan', 'Scott'),
#  ('Sophia', 'Moore'),
#  ('Emma', 'Miller'),
#  ('George', 'Martin'),
#  ('Bob', 'Johnson'),
#  ('Charlotte', 'Jackson'),
#  ('Amelia', 'Harris'),
#  ('John', 'Doe'),
#  ('Mike', 'Davis'),
#  ('Ava', 'Coleman'),
#  ('Mia', 'Anderson'),
#  ('Abigail', 'Allen')]

# %% [markdown]
# ##### order by  column

# %% [markdown]
# like ascending, descending

# %% [markdown]
# Order By Based on column no. without typing column
# name

# %%
cursor.execute("select CustomerFirstName, CustomerLastName from customer order by 1 desc")

# %%
cursor.fetchall()
# Out:
# [('William', 'Thomas'),
#  ('Tom', 'Wilson'),
#  ('Sophia', 'Moore'),
#  ('Oliver', 'Taylor'),
#  ('Mike', 'Davis'),
#  ('Mia', 'Anderson'),
#  ('Logan', 'Scott'),
#  ('John', 'Doe'),
#  ('Jane', 'Smith'),
#  ('James', 'White'),
#  ('Harriet', 'Thompson'),
#  ('George', 'Martin'),
#  ('Emma', 'Miller'),
#  ('Charlotte', 'Jackson'),
#  ('Bob', 'Johnson'),
#  ('Benjamin', 'Walker'),
#  ('Ava', 'Coleman'),
#  ('Amelia', 'Harris'),
#  ('Alice', 'Williams'),
#  ('Abigail', 'Allen')]

# %% [markdown]
# distinct: only show unique value in a column

# %%
cursor.execute("select distinct CustomerLastName from customer order by customerLastName")

# %%
cursor.fetchall()
# Out:
# [('Allen',),
#  ('Anderson',),
#  ('Coleman',),
#  ('Davis',),
#  ('Doe',),
#  ('Harris',),
#  ('Jackson',),
#  ('Johnson',),
#  ('Martin',),
#  ('Miller',),
#  ('Moore',),
#  ('Scott',),
#  ('Smith',),
#  ('Taylor',),
#  ('Thomas',),
#  ('Thompson',),
#  ('Walker',),
#  ('White',),
#  ('Williams',),
#  ('Wilson',)]

# %% [markdown]
# Save table to another table

# %%
cursor.execute("create table temp(CustomerLastName varchar(20))")

# %% [markdown]
# -into file_name: save result in another table (BASE TABLE)

# %%
cursor.execute("select distinct CustomerLastName into temp from customer order by CustomerLastName")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File d:\a27_YEARS_OLD\mysql\venv\Lib\site-packages\mysql\connector\connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Undeclared variable: temp
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 cursor.execute("select distinct CustomerLastName into temp from customer order by CustomerLastName")
#
# File d:\a27_YEARS_OLD\mysql\venv\Lib\site-packages\mysql\connector\cursor_cext.py:351, in CMySQLCursor.execute(self, operation, params, map_results)
#     343 self._executed = (
#     344     self._stmt_partition["single_stmts"].popleft()
#     345     if map_results
#     346     else self._stmt_partition["mappable_stmt"]
#     347 )
#     349 try:
#     350     self._handle_result(
# --> 351         self._connection.cmd_query(
#     352             self._stmt_partition["mappable_stmt"],
#     353             raw=self._raw,
#     354             buffered=self._buffered,
#     355             raw_as_string=self._raw_as_string,
#     356         )
#     357     )
#     358 except MySQLInterfaceError as err:
#     359     raise get_mysql_exception(
#     360         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     361     ) from err
#
# File d:\a27_YEARS_OLD\mysql\venv\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File d:\a27_YEARS_OLD\mysql\venv\Lib\site-packages\mysql\connector\connection_cext.py:763, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#    (...)
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
# --> 763     raise get_mysql_exception(
#     764         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     765     ) from err
#     766 except AttributeError as err:
#     767     addr = (
#     768         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     769     )
#
# ProgrammingError: 1327 (42000): Undeclared variable: temp

# %% [markdown]
# Like (search something) in column

# %% [markdown]
# (underscore sign) _ is only specific for one character only -- (percent sign) % represents zero, one, or multiple characters

# %%
cursor.execute("select * from customer where customerLastName like '_M%' ")

# %%
cursor.fetchall()
# Out:
# [(2,
#   'Jane',
#   'Smith',
#   '456 High St',
#   'Othertown',
#   'Sydney',
#   '2000',
#   '0434 567 890')]

# %% [markdown]
# In (search something)

# %% [markdown]
# in column values

# %%
cursor.execute("select * from customer where customerLastName in ('Miller','Martin','Moore')")

# %%
cursor.fetchall()
# Out:
# [(6,
#   'Emma',
#   'Miller',
#   '345 Maple St',
#   'Elsewhere',
#   'Hobart',
#   '7000',
#   '0433 456 789'),
#  (8,
#   'Sophia',
#   'Moore',
#   '234 Cedar St',
#   'This town',
#   'Canberra',
#   '2600',
#   '0488 901 234'),
#  (15,
#   'George',
#   'Martin',
#   '567 Oak St',
#   'Someplace',
#   'Cairns',
#   '4870',
#   '0459 012 345')]

# %%
cursor.execute("select * from customer where customerLastName like 'M%' ") # staring with M

# %%
cursor.fetchall()
# Out:
# [(6,
#   'Emma',
#   'Miller',
#   '345 Maple St',
#   'Elsewhere',
#   'Hobart',
#   '7000',
#   '0433 456 789'),
#  (8,
#   'Sophia',
#   'Moore',
#   '234 Cedar St',
#   'This town',
#   'Canberra',
#   '2600',
#   '0488 901 234'),
#  (15,
#   'George',
#   'Martin',
#   '567 Oak St',
#   'Someplace',
#   'Cairns',
#   '4870',
#   '0459 012 345')]

# %% [markdown]
# -> (search something)

# %% [markdown]
# in column values greater than , less than or equal to

# %%
cursor.execute("select * from customer where customerLastName > 'Brown' or customerLastName >'Cross' ")

# %%
cursor.fetchall()
# Out:
# [(1,
#   'John',
#   'Doe',
#   '123 Main St',
#   'Anytown',
#   'Melbourne',
#   '3000',
#   '0412 345 678'),
#  (2,
#   'Jane',
#   'Smith',
#   '456 High St',
#   'Othertown',
#   'Sydney',
#   '2000',
#   '0434 567 890'),
#  (3,
#   'Bob',
#   'Johnson',
#   '789 Low St',
#   'Thistown',
#   'Brisbane',
#   '4000',
#   '0456 789 012'),
#  (4,
#   'Alice',
#   'Williams',
#   '321 Elm St',
#   'Thatville',
#   'Perth',
#   '6000',
#   '0487 890 123'),
#  (5,
#   'Mike',
#   'Davis',
#   '901 Oak St',
#   'Someplace',
#   'Adelaide',
#   '5000',
#   '0411 234 567'),
#  (6,
#   'Emma',
#   'Miller',
#   '345 Maple St',
#   'Elsewhere',
#   'Hobart',
#   '7000',
#   '0433 456 789'),
#  (7,
#   'Tom',
#   'Wilson',
#   '678 Pine St',
#   'Another town',
#   'Darwin',
#   '0800',
#   '0455 678 901'),
#  (8,
#   'Sophia',
#   'Moore',
#   '234 Cedar St',
#   'This town',
#   'Canberra',
#   '2600',
#   '0488 901 234'),
#  (9,
#   'Oliver',
#   'Taylor',
#   '567 Cypress St',
#   'That town',
#   'Gold Coast',
#   '4217',
#   '0414 567 890'),
#  (11,
#   'William',
#   'Thomas',
#   '345 Spruce St',
#   'Anytown',
#   'Central Coast',
#   '2250',
#   '0457 789 012'),
#  (12,
#   'Charlotte',
#   'Jackson',
#   '678 Fir St',
#   'Othertown',
#   'Wollongong',
#   '2500',
#   '0489 012 345'),
#  (13,
#   'James',
#   'White',
#   '901 Beech St',
#   'Thistown',
#   'Geelong',
#   '3220',
#   '0416 789 012'),
#  (14,
#   'Amelia',
#   'Harris',
#   '234 Ash St',
#   'Thatville',
#   'Townsville',
#   '4810',
#   '0438 901 234'),
#  (15,
#   'George',
#   'Martin',
#   '567 Oak St',
#   'Someplace',
#   'Cairns',
#   '4870',
#   '0459 012 345'),
#  (16,
#   'Harriet',
#   'Thompson',
#   '890 Maple St',
#   'Elsewhere',
#   'Toowoomba',
#   '4350',
#   '0481 234 567'),
#  (17,
#   'Benjamin',
#   'Walker',
#   '345 Pine St',
#   'Another town',
#   'Ballarat',
#   '3350',
#   '0418 901 234'),
#  (19,
#   'Logan',
#   'Scott',
#   '901 Cypress St',
#   'That town',
#   'Mackay',
#   '4740',
#   '0450 123 456'),
#  (20,
#   'Ava',
#   'Coleman',
#   '234 Walnut St',
#   'Some town',
#   'Rockhampton',
#   '4700',
#   '0482 345 678')]

# %% [markdown]
# -> <> (Not Equal)

# %%
cursor.execute("select * from customer where customerLastName <> 'Brown' ")

# %%
cursor.fetchall()
# Out:
# [(1,
#   'John',
#   'Doe',
#   '123 Main St',
#   'Anytown',
#   'Melbourne',
#   '3000',
#   '0412 345 678'),
#  (2,
#   'Jane',
#   'Smith',
#   '456 High St',
#   'Othertown',
#   'Sydney',
#   '2000',
#   '0434 567 890'),
#  (3,
#   'Bob',
#   'Johnson',
#   '789 Low St',
#   'Thistown',
#   'Brisbane',
#   '4000',
#   '0456 789 012'),
#  (4,
#   'Alice',
#   'Williams',
#   '321 Elm St',
#   'Thatville',
#   'Perth',
#   '6000',
#   '0487 890 123'),
#  (5,
#   'Mike',
#   'Davis',
#   '901 Oak St',
#   'Someplace',
#   'Adelaide',
#   '5000',
#   '0411 234 567'),
#  (6,
#   'Emma',
#   'Miller',
#   '345 Maple St',
#   'Elsewhere',
#   'Hobart',
#   '7000',
#   '0433 456 789'),
#  (7,
#   'Tom',
#   'Wilson',
#   '678 Pine St',
#   'Another town',
#   'Darwin',
#   '0800',
#   '0455 678 901'),
#  (8,
#   'Sophia',
#   'Moore',
#   '234 Cedar St',
#   'This town',
#   'Canberra',
#   '2600',
#   '0488 901 234'),
#  (9,
#   'Oliver',
#   'Taylor',
#   '567 Cypress St',
#   'That town',
#   'Gold Coast',
#   '4217',
#   '0414 567 890'),
#  (10,
#   'Mia',
#   'Anderson',
#   '890 Walnut St',
#   'Some town',
#   'Newcastle',
#   '2300',
#   '0435 678 901'),
#  (11,
#   'William',
#   'Thomas',
#   '345 Spruce St',
#   'Anytown',
#   'Central Coast',
#   '2250',
#   '0457 789 012'),
#  (12,
#   'Charlotte',
#   'Jackson',
#   '678 Fir St',
#   'Othertown',
#   'Wollongong',
#   '2500',
#   '0489 012 345'),
#  (13,
#   'James',
#   'White',
#   '901 Beech St',
#   'Thistown',
#   'Geelong',
#   '3220',
#   '0416 789 012'),
#  (14,
#   'Amelia',
#   'Harris',
#   '234 Ash St',
#   'Thatville',
#   'Townsville',
#   '4810',
#   '0438 901 234'),
#  (15,
#   'George',
#   'Martin',
#   '567 Oak St',
#   'Someplace',
#   'Cairns',
#   '4870',
#   '0459 012 345'),
#  (16,
#   'Harriet',
#   'Thompson',
#   '890 Maple St',
#   'Elsewhere',
#   'Toowoomba',
#   '4350',
#   '0481 234 567'),
#  (17,
#   'Benjamin',
#   'Walker',
#   '345 Pine St',
#   'Another town',
#   'Ballarat',
#   '3350',
#   '0418 901 234'),
#  (18,
#   'Abigail',
#   'Allen',
#   '678 Cedar St',
#   'This town',
#   'Bendigo',
#   '3550',
#   '0439 012 345'),
#  (19,
#   'Logan',
#   'Scott',
#   '901 Cypress St',
#   'That town',
#   'Mackay',
#   '4740',
#   '0450 123 456'),
#  (20,
#   'Ava',
#   'Coleman',
#   '234 Walnut St',
#   'Some town',
#   'Rockhampton',
#   '4700',
#   '0482 345 678')]

# %% [markdown]
#  IS NULL

# %%
cursor.execute("select * from customer where customerLastName IS NULL ")

# %%
cursor.fetchall()
# Out:
# []

# %% [markdown]
#  IS NOT NULL

# %%
cursor.execute("select * from customer where customerLastName IS NOT NULL")

# %%
cursor.fetchall()
# Out:
# [(1,
#   'John',
#   'Doe',
#   '123 Main St',
#   'Anytown',
#   'Melbourne',
#   '3000',
#   '0412 345 678'),
#  (2,
#   'Jane',
#   'Smith',
#   '456 High St',
#   'Othertown',
#   'Sydney',
#   '2000',
#   '0434 567 890'),
#  (3,
#   'Bob',
#   'Johnson',
#   '789 Low St',
#   'Thistown',
#   'Brisbane',
#   '4000',
#   '0456 789 012'),
#  (4,
#   'Alice',
#   'Williams',
#   '321 Elm St',
#   'Thatville',
#   'Perth',
#   '6000',
#   '0487 890 123'),
#  (5,
#   'Mike',
#   'Davis',
#   '901 Oak St',
#   'Someplace',
#   'Adelaide',
#   '5000',
#   '0411 234 567'),
#  (6,
#   'Emma',
#   'Miller',
#   '345 Maple St',
#   'Elsewhere',
#   'Hobart',
#   '7000',
#   '0433 456 789'),
#  (7,
#   'Tom',
#   'Wilson',
#   '678 Pine St',
#   'Another town',
#   'Darwin',
#   '0800',
#   '0455 678 901'),
#  (8,
#   'Sophia',
#   'Moore',
#   '234 Cedar St',
#   'This town',
#   'Canberra',
#   '2600',
#   '0488 901 234'),
#  (9,
#   'Oliver',
#   'Taylor',
#   '567 Cypress St',
#   'That town',
#   'Gold Coast',
#   '4217',
#   '0414 567 890'),
#  (10,
#   'Mia',
#   'Anderson',
#   '890 Walnut St',
#   'Some town',
#   'Newcastle',
#   '2300',
#   '0435 678 901'),
#  (11,
#   'William',
#   'Thomas',
#   '345 Spruce St',
#   'Anytown',
#   'Central Coast',
#   '2250',
#   '0457 789 012'),
#  (12,
#   'Charlotte',
#   'Jackson',
#   '678 Fir St',
#   'Othertown',
#   'Wollongong',
#   '2500',
#   '0489 012 345'),
#  (13,
#   'James',
#   'White',
#   '901 Beech St',
#   'Thistown',
#   'Geelong',
#   '3220',
#   '0416 789 012'),
#  (14,
#   'Amelia',
#   'Harris',
#   '234 Ash St',
#   'Thatville',
#   'Townsville',
#   '4810',
#   '0438 901 234'),
#  (15,
#   'George',
#   'Martin',
#   '567 Oak St',
#   'Someplace',
#   'Cairns',
#   '4870',
#   '0459 012 345'),
#  (16,
#   'Harriet',
#   'Thompson',
#   '890 Maple St',
#   'Elsewhere',
#   'Toowoomba',
#   '4350',
#   '0481 234 567'),
#  (17,
#   'Benjamin',
#   'Walker',
#   '345 Pine St',
#   'Another town',
#   'Ballarat',
#   '3350',
#   '0418 901 234'),
#  (18,
#   'Abigail',
#   'Allen',
#   '678 Cedar St',
#   'This town',
#   'Bendigo',
#   '3550',
#   '0439 012 345'),
#  (19,
#   'Logan',
#   'Scott',
#   '901 Cypress St',
#   'That town',
#   'Mackay',
#   '4740',
#   '0450 123 456'),
#  (20,
#   'Ava',
#   'Coleman',
#   '234 Walnut St',
#   'Some town',
#   'Rockhampton',
#   '4700',
#   '0482 345 678')]

# %% [markdown]
# between

# %%
cursor.execute("select * from sale where saleUnitPrice between 1000 and 1500")

# %%
cursor.fetchall()
# Out:
# [(1, 1, 1, 1, datetime.date(2022, 1, 1), 2, Decimal('1000.00')),
#  (4, 3, 1, 1, datetime.date(2022, 1, 15), 1, Decimal('1000.00')),
#  (6, 5, 5, 5, datetime.date(2022, 1, 25), 1, Decimal('1500.00')),
#  (7, 6, 6, 6, datetime.date(2022, 2, 1), 3, Decimal('1200.00')),
#  (12, 1, 1, 1, datetime.date(2022, 3, 1), 3, Decimal('1000.00')),
#  (16, 5, 5, 5, datetime.date(2022, 3, 20), 1, Decimal('1500.00')),
#  (17, 6, 6, 6, datetime.date(2022, 4, 1), 3, Decimal('1200.00'))]

# %% [markdown]
# count

# %% [markdown]
# returns the number of rows in a table -- AS means aliasing, temporary giving name to a column/ table

# %%
cursor.execute("select count(*) as number_of_record from customer where customerFirstName like '%s'")

# %%
cursor.fetchall()
# Out:
# [(1,)]

# %% [markdown]
# sum

# %% [markdown]
# create a record contain employee id , first name , last name and total order count , total sale count for each
# employee

# %% [markdown]
# from different table like sale and customer from sale join employee on employee id

# %%
cursor.execute("""select sale.EmployeeId ,employee.EmployeeFirstName, employee.EmployeeLastName , count(*) as Number_of_order ,  sum(sale.SaleQuantity) as Total_Quantity  from sale join employee on sale.EmployeeId =employee.EmployeeId group by sale.employeeId ,EmployeeFirstName, EmployeeLastName """)

# %%
cursor.fetchall()
# Out:
# [(1, 'John', 'Doe', 3, Decimal('6')),
#  (2, 'Jane', 'Smith', 2, Decimal('3')),
#  (3, 'Bob', 'Johnson', 2, Decimal('4')),
#  (4, 'Alice', 'Williams', 2, Decimal('4')),
#  (5, 'Mike', 'Davis', 2, Decimal('2')),
#  (6, 'Emma', 'Miller', 2, Decimal('6')),
#  (7, 'Tom', 'Wilson', 2, Decimal('4')),
#  (8, 'Sophia', 'Moore', 2, Decimal('2')),
#  (9, 'Oliver', 'Taylor', 2, Decimal('4')),
#  (10, 'Mia', 'Anderson', 1, Decimal('1'))]

# %% [markdown]
# count month wise sales and amount

# %%
cursor.execute('''select month(SaleDate) as month, count(*) as number_of_sale ,sum(SaleQuantity*SaleUnitPrice) as total_amount from sale group by month(SaleDate)''')

# %%
cursor.fetchall()
# Out:
# [(1, 6, Decimal('11250.00')),
#  (2, 5, Decimal('17200.00')),
#  (3, 5, Decimal('10250.00')),
#  (4, 4, Decimal('14400.00'))]

# %%
cursor.execute('''create table salary (
                    EmployeeID int not null references employee(EmployeeID),
                    Salary int)'''
)

# %%
cursor.execute("""
    INSERT INTO salary (
        EmployeeID, 
        Salary
    ) 
    VALUES 
        (1, 50000),
        (2, 60000),
        (3, 70000),
        (4, 55000),
        (5, 65000),
        (6, 75000),
        (7, 58000),
        (8, 68000),
        (9, 78000),
        (10, 60000)
""")

# %%
conn.commit()

# %%
cursor.execute("select * from salary")

# %%
cursor.fetchall()
# Out:
# [(1, 50000),
#  (2, 60000),
#  (3, 70000),
#  (4, 55000),
#  (5, 65000),
#  (6, 75000),
#  (7, 58000),
#  (8, 68000),
#  (9, 78000),
#  (10, 60000)]

# %% [markdown]
# max

# %%
cursor.execute('''SELECT max(Salary) from salary''')

# %%
cursor.fetchall()
# Out:
# [(78000,)]

# %%
cursor.execute('''SELECT min(Salary) from salary''')

# %%
cursor.fetchall()
# Out:
# [(50000,)]

# %%
cursor.execute('''SELECT avg(Salary) from salary''')

# %%
cursor.fetchall()
# Out:
# [(Decimal('63900.0000'),)]

# %% [markdown]
# having
